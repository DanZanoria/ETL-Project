# %%
# Dependencies and datebase credentials
import pandas as pd
from sqlalchemy import create_engine
from config import user_nm
from config import user_pw
from config import user_port
import country_converter as coco

# %% [markdown]
# # Extraction

# %% [markdown]
# ### 2015 world happiness index

# %%
world_happiness_index_2015_file = "Resources/world_happiness_index_2015.csv"
world_happiness_index_2015_df = pd.read_csv(world_happiness_index_2015_file)
world_happiness_index_2015_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
len(world_happiness_index_2015_df)
# Out:
# 158

# %%
world_happiness_index_2015_df['Country'].nunique()
# Out:
# 158

# %% [markdown]
# ### 2016 world happiness index

# %%
world_happiness_index_2016_file = "Resources/world_happiness_index_2016.csv"
world_happiness_index_2016_df = pd.read_csv(world_happiness_index_2016_file)
world_happiness_index_2016_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
len(world_happiness_index_2016_df)
# Out:
# 157

# %%
world_happiness_index_2016_df['Country'].nunique()
# Out:
# 157

# %% [markdown]
# ### 2017 world happiness index

# %%
world_happiness_index_2017_file = "Resources/world_happiness_index_2017.csv"
world_happiness_index_2017_df = pd.read_csv(world_happiness_index_2017_file)
world_happiness_index_2017_df.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
len(world_happiness_index_2017_df)
# Out:
# 155

# %%
world_happiness_index_2017_df['Country'].nunique()
# Out:
# 155

# %% [markdown]
# ### Alcohol abuse

# %%
alcoholSubstanceAbuse_file = "Resources/alcoholSubstanceAbuse.csv"
alcoholSubstanceAbuse_df = pd.read_csv(alcoholSubstanceAbuse_file)
alcoholSubstanceAbuse_df.head()
# Out:
#       Location  Period                                          Indicator  \
# 0  Afghanistan    2018  Total (recorded+unrecorded) alcohol per capita...
# 1  Afghanistan    2018  Total (recorded+unrecorded) alcohol per capita...
# 2  Afghanistan    2018  Total (recorded+unrecorded) alcohol per capita...
# 3  Afghanistan    2015  Total (recorded+unrecorded) alcohol per capita...
# 4  Afghanistan    2015  Total (recorded+unrecorded) alcohol per capita...
#
#          Dim1  First Tooltip
# 0  Both sexes          0.210
# 1        Male          0.360
# 2      Female          0.055
# 3  Both sexes          0.210
# 4        Male          0.350

# %%
len(alcoholSubstanceAbuse_df)
# Out:
# 2787

# %%
alcoholSubstanceAbuse_df['Location'].nunique()
# Out:
# 188

# %% [markdown]
# ### Antidepressant consumption

# %%
antidepressant_consumption_file = "Resources/List_of_countries_by_antidepressant_consumption.csv"
antidepressant_consumption_df = pd.read_csv(antidepressant_consumption_file)
antidepressant_consumption_df.fillna('', inplace=True)
antidepressant_consumption_df.head()
# Out:
#           Country  Defined daily dosage per 1 000 inhabitants per day  Year  \
# 0         Iceland                                              141.4   2017
# 1       Australia                                              106.7   2016
# 2        Portugal                                              103.6   2017
# 3  United Kingdom                                              100.1   2016
# 4          Canada                                               99.6   2017
#
#   Data include drugs dispensed in hospitals  \
# 0
# 1
# 2
# 3
# 4
#
#                    Data include non-reimbursed drugs  \
# 0
# 1
# 2  Data include both reimbursed and non-reimburse...
# 3
# 4
#
#                               Data include OTC drugs               Notes
# 0
# 1
# 2     Yes, but only OTC products sold in pharmacies.
# 3
# 4  See note Generally, claims for OTC drugs are n...  Provisional value.

# %%
len(antidepressant_consumption_df)
# Out:
# 29

# %%
antidepressant_consumption_df['Country'].nunique()
# Out:
# 29

# %% [markdown]
# # Transform

# %% [markdown]
# #### World happiness 2015

# %%
world_happiness_index_2015_df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
del world_happiness_index_2015_df['Region']
del world_happiness_index_2015_df['Standard Error']
world_happiness_index_2015_df.rename(columns = {'Country':'country',
                                                    'Happiness Rank':'happiness_rank',
                                                    'Happiness Score':'happiness_score',
                                                    'Economy (GDP per Capita)':'gdp_per_capita',
                                                    'Family':'family',
                                                    'Health (Life Expectancy)':'life_expectancy',
                                                    'Freedom':'freedom',
                                                    'Generosity':'generosity',
                                                    'Trust (Government Corruption)':'trust_government',
                                                    'Dystopia Residual':'dystopia_residual'}, inplace = True)
world_happiness_index_2015_df['year']=2015
world_happiness_index_2015_df.head()
# Out:
#        country  happiness_rank  happiness_score  gdp_per_capita   family  \
# 0  Switzerland               1            7.587         1.39651  1.34951
# 1      Iceland               2            7.561         1.30232  1.40223
# 2      Denmark               3            7.527         1.32548  1.36058
# 3       Norway               4            7.522         1.45900  1.33095
# 4       Canada               5            7.427         1.32629  1.32261
#
#    life_expectancy  freedom  trust_government  generosity  dystopia_residual  \
# 0          0.94143  0.66557           0.41978     0.29678            2.51738
# 1          0.94784  0.62877           0.14145     0.43630            2.70201
# 2          0.87464  0.64938           0.48357     0.34139            2.49204
# 3          0.88521  0.66973           0.36503     0.34699            2.46531
# 4          0.90563  0.63297           0.32957     0.45811            2.45176
#
#    year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %% [markdown]
# #### World happiness 2016

# %%
world_happiness_index_2016_df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
del world_happiness_index_2016_df['Region']
del world_happiness_index_2016_df['Lower Confidence Interval']
del world_happiness_index_2016_df['Upper Confidence Interval']
world_happiness_index_2016_df.rename(columns = {'Country':'country',
                                                    'Happiness Rank':'happiness_rank',
                                                    'Happiness Score':'happiness_score',
                                                    'Economy (GDP per Capita)':'gdp_per_capita',
                                                    'Family':'family',
                                                    'Health (Life Expectancy)':'life_expectancy',
                                                    'Freedom':'freedom',
                                                    'Generosity':'generosity',
                                                    'Trust (Government Corruption)':'trust_government',
                                                    'Dystopia Residual':'dystopia_residual'}, inplace = True)
world_happiness_index_2016_df['year']=2016
world_happiness_index_2016_df.head()
# Out:
#        country  happiness_rank  happiness_score  gdp_per_capita   family  \
# 0      Denmark               1            7.526         1.44178  1.16374
# 1  Switzerland               2            7.509         1.52733  1.14524
# 2      Iceland               3            7.501         1.42666  1.18326
# 3       Norway               4            7.498         1.57744  1.12690
# 4      Finland               5            7.413         1.40598  1.13464
#
#    life_expectancy  freedom  trust_government  generosity  dystopia_residual  \
# 0          0.79504  0.57941           0.44453     0.36171            2.73939
# 1          0.86303  0.58557           0.41203     0.28083            2.69463
# 2          0.86733  0.56624           0.14975     0.47678            2.83137
# 3          0.79579  0.59609           0.35776     0.37895            2.66465
# 4          0.81091  0.57104           0.41004     0.25492            2.82596
#
#    year
# 0  2016
# 1  2016
# 2  2016
# 3  2016
# 4  2016

# %% [markdown]
# #### World happiness 2017

# %%
world_happiness_index_2017_df.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
del world_happiness_index_2017_df['Whisker.high']
del world_happiness_index_2017_df['Whisker.low']
world_happiness_index_2017_df.rename(columns = {'Country':'country',
                                                    'Happiness.Rank':'happiness_rank',
                                                    'Happiness.Score':'happiness_score',
                                                    'Economy..GDP.per.Capita.':'gdp_per_capita',
                                                    'Family':'family',
                                                    'Health..Life.Expectancy.':'life_expectancy',
                                                    'Freedom':'freedom',
                                                    'Generosity':'generosity',
                                                    'Trust..Government.Corruption.':'trust_government',
                                                    'Dystopia.Residual':'dystopia_residual'}, inplace = True)
world_happiness_index_2017_df = world_happiness_index_2017_df[['country', 'happiness_rank', 'happiness_score', 'gdp_per_capita',
       'family', 'life_expectancy', 'freedom', 'trust_government', 'generosity', 'dystopia_residual']]
world_happiness_index_2017_df['year']=2017
world_happiness_index_2017_df.head()
# Out:
#        country  happiness_rank  happiness_score  gdp_per_capita    family  \
# 0       Norway               1            7.537        1.616463  1.533524
# 1      Denmark               2            7.522        1.482383  1.551122
# 2      Iceland               3            7.504        1.480633  1.610574
# 3  Switzerland               4            7.494        1.564980  1.516912
# 4      Finland               5            7.469        1.443572  1.540247
#
#    life_expectancy   freedom  trust_government  generosity  dystopia_residual  \
# 0         0.796667  0.635423          0.315964    0.362012           2.277027
# 1         0.792566  0.626007          0.400770    0.355280           2.313707
# 2         0.833552  0.627163          0.153527    0.475540           2.322715
# 3         0.858131  0.620071          0.367007    0.290549           2.276716
# 4         0.809158  0.617951          0.382612    0.245483           2.430182
#
#    year
# 0  2017
# 1  2017
# 2  2017
# 3  2017
# ...

# %%
# appending all the world happiness datasets
world_happiness_index_df = world_happiness_index_2015_df.append(world_happiness_index_2016_df, ignore_index = True)
world_happiness_index_df = world_happiness_index_df.append(world_happiness_index_2017_df, ignore_index = True)
world_happiness_index_df.head(-5)
# Out:
#          country  happiness_rank  happiness_score  gdp_per_capita    family  \
# 0    Switzerland               1            7.587        1.396510  1.349510
# 1        Iceland               2            7.561        1.302320  1.402230
# 2        Denmark               3            7.527        1.325480  1.360580
# 3         Norway               4            7.522        1.459000  1.330950
# 4         Canada               5            7.427        1.326290  1.322610
# ..           ...             ...              ...             ...       ...
# 460        Yemen             146            3.593        0.591683  0.935382
# 461  South Sudan             147            3.591        0.397249  0.601323
# 462      Liberia             148            3.533        0.119042  0.872118
# 463       Guinea             149            3.507        0.244550  0.791245
# 464         Togo             150            3.495        0.305445  0.431883
#
# ...

# %%
# Creating a dataframe for standardized county names for each country in world_happiness_index_df
entity1= list(set(world_happiness_index_df["country"]))
standard_names1 = coco.convert(names=entity1, to='name_short')
standardized_names1_df = pd.DataFrame({"country" : entity1,
                                      "standard_names": standard_names1}).sort_values(by = "country").reset_index(drop = True)
standardized_names1_df.head()
# Out:
#        country standard_names
# 0  Afghanistan    Afghanistan
# 1      Albania        Albania
# 2      Algeria        Algeria
# 3       Angola         Angola
# 4    Argentina      Argentina

# %%
# joining with world_happiness_index_df to get the standardized names
world_happiness_index_df = pd.merge(world_happiness_index_df, standardized_names1_df, how = "left", left_on='country', right_on='country')
del world_happiness_index_df['country']
world_happiness_index_df.rename(columns = {'standard_names': 'country'}, inplace =True)
world_happiness_index_df= world_happiness_index_df[['country', 'happiness_rank', 'happiness_score', 'gdp_per_capita',
       'family', 'life_expectancy', 'freedom', 'trust_government',
       'generosity', 'dystopia_residual', 'year']]
world_happiness_index_df.head(-5)
# Out:
#          country  happiness_rank  happiness_score  gdp_per_capita    family  \
# 0    Switzerland               1            7.587        1.396510  1.349510
# 1        Iceland               2            7.561        1.302320  1.402230
# 2        Denmark               3            7.527        1.325480  1.360580
# 3         Norway               4            7.522        1.459000  1.330950
# 4         Canada               5            7.427        1.326290  1.322610
# ..           ...             ...              ...             ...       ...
# 460        Yemen             146            3.593        0.591683  0.935382
# 461  South Sudan             147            3.591        0.397249  0.601323
# 462      Liberia             148            3.533        0.119042  0.872118
# 463       Guinea             149            3.507        0.244550  0.791245
# 464         Togo             150            3.495        0.305445  0.431883
#
# ...

# %% [markdown]
# #### World alcohol consumption per capita

# %%
alcoholSubstanceAbuse_df.columns
# Out:
# Index(['Location', 'Period', 'Indicator', 'Dim1', 'First Tooltip'], dtype='object')

# %%
del alcoholSubstanceAbuse_df['Indicator']
alcoholSubstanceAbuse_df.rename(columns = {'Location' : 'country', 'Period':'year',
                                                'Dim1':'gender','First Tooltip': 'per_capita_consumption'}, inplace = True)
alcoholSubstanceAbuse_df.head()
# Out:
#        country  year      gender  per_capita_consumption
# 0  Afghanistan  2018  Both sexes                   0.210
# 1  Afghanistan  2018        Male                   0.360
# 2  Afghanistan  2018      Female                   0.055
# 3  Afghanistan  2015  Both sexes                   0.210
# 4  Afghanistan  2015        Male                   0.350

# %%
# Creating a dataframe for standardized county names for each country in alcoholSubstanceAbuse_df
entity2= list(set(alcoholSubstanceAbuse_df["country"]))
standard_names2 = coco.convert(names=entity2, to='name_short')
standardized_names2_df = pd.DataFrame({"country" : entity2,
                                      "standard_names": standard_names2}).sort_values(by = "country").reset_index(drop = True)
standardized_names2_df.head()
# Out:
#        country standard_names
# 0  Afghanistan    Afghanistan
# 1      Albania        Albania
# 2      Algeria        Algeria
# 3      Andorra        Andorra
# 4       Angola         Angola

# %%
# joining with alcoholSubstanceAbuse_df to get the standardized names
alcoholSubstanceAbuse_df = pd.merge(alcoholSubstanceAbuse_df, standardized_names2_df, how = "left", left_on='country', right_on='country')
del alcoholSubstanceAbuse_df['country']
alcoholSubstanceAbuse_df.rename(columns = {'standard_names': 'country'}, inplace =True)
alcoholSubstanceAbuse_df= alcoholSubstanceAbuse_df[['country', 'year', 'gender', 'per_capita_consumption']]
alcoholSubstanceAbuse_df.head(-5)
# Out:
#           country  year      gender  per_capita_consumption
# 0     Afghanistan  2018  Both sexes                   0.210
# 1     Afghanistan  2018        Male                   0.360
# 2     Afghanistan  2018      Female                   0.055
# 3     Afghanistan  2015  Both sexes                   0.210
# 4     Afghanistan  2015        Male                   0.350
# ...           ...   ...         ...                     ...
# 2777     Zimbabwe  2015      Female                   1.720
# 2778     Zimbabwe  2010  Both sexes                   3.930
# 2779     Zimbabwe  2010        Male                   6.710
# 2780     Zimbabwe  2010      Female                   1.390
# 2781     Zimbabwe  2005  Both sexes                   2.770
#
# [2782 rows x 4 columns]

# %% [markdown]
# #### World antidepressant consumption per 1000 people per day

# %%
antidepressant_consumption_df.columns
# Out:
# Index(['Country', 'Defined daily dosage per 1 000 inhabitants per day', 'Year',
#        'Data include drugs dispensed in hospitals',
#        'Data include non-reimbursed drugs', 'Data include OTC drugs', 'Notes'],
#       dtype='object')

# %%
antidepressant_consumption_df['notes']= antidepressant_consumption_df['Data include drugs dispensed in hospitals']+ \
                                        antidepressant_consumption_df['Data include non-reimbursed drugs']+ \
                                        antidepressant_consumption_df['Data include OTC drugs']+\
                                        antidepressant_consumption_df['Notes']
del antidepressant_consumption_df['Data include drugs dispensed in hospitals']
del antidepressant_consumption_df['Data include non-reimbursed drugs']
del antidepressant_consumption_df['Data include OTC drugs']
del antidepressant_consumption_df['Notes']
antidepressant_consumption_df.rename(columns = {'Country': 'country',
                                                     'Defined daily dosage per 1 000 inhabitants per day': 'daily_dosage_per_1k',
                                                     'Year': 'year'}, inplace=True)
antidepressant_consumption_df.head()
# Out:
#           country  daily_dosage_per_1k  year  \
# 0         Iceland                141.4  2017
# 1       Australia                106.7  2016
# 2        Portugal                103.6  2017
# 3  United Kingdom                100.1  2016
# 4          Canada                 99.6  2017
#
#                                                notes
# 0
# 1
# 2  Data include both reimbursed and non-reimburse...
# 3
# 4  See note Generally, claims for OTC drugs are n...

# %%
# Creating a dataframe for standardized county names for each country in antidepressant_consumption_df
entity3= list(set(antidepressant_consumption_df["country"]))
standard_names3 = coco.convert(names=entity3, to='name_short')
standardized_names3_df = pd.DataFrame({"country" : entity3,
                                      "standard_names": standard_names3}).sort_values(by = "country").reset_index(drop = True)
standardized_names3_df.head()
# Out:
#      country standard_names
# 0  Australia      Australia
# 1    Austria        Austria
# 2    Belgium        Belgium
# 3     Canada         Canada
# 4      Chile          Chile

# %%
# joining with antidepressant_consumption_df to get the standardized names
antidepressant_consumption_df = pd.merge(antidepressant_consumption_df, standardized_names3_df, how = "left", left_on='country', right_on='country')
del antidepressant_consumption_df['country']
antidepressant_consumption_df.rename(columns = {'standard_names': 'country'}, inplace =True)
antidepressant_consumption_df= antidepressant_consumption_df[['country', 'daily_dosage_per_1k', 'year', 'notes']]
antidepressant_consumption_df.head(-5)
# Out:
#            country  daily_dosage_per_1k  year  \
# 0          Iceland                141.4  2017
# 1        Australia                106.7  2016
# 2         Portugal                103.6  2017
# 3   United Kingdom                100.1  2016
# 4           Canada                 99.6  2017
# 5           Sweden                 96.8  2017
# 6          Belgium                 79.0  2016
# 7          Denmark                 77.0  2015
# 8            Spain                 75.5  2016
# 9      New Zealand                 72.8  2014
# 10         Finland                 67.6  2016
# 11         Austria                 60.5  2016
# 12        Slovenia                 58.6  2016
# 13          Norway                 57.1  2017
# 14  Czech Republic                 57.1  2016
# 15         Germany                 56.5  2016
# 16      Luxembourg                 52.7  2017
# 17          France                 49.8  2009
# 18          Israel                 49.2  2017
# ...

# %% [markdown]
# # Connection to postgres database

# %%
connection_string = f"{user_nm}:{user_pw}@localhost:{user_port}/world_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['happiness', 'alcohol_consumption', 'antidepressant_consumption']

# %% [markdown]
# # Load DataFrames into database

# %%
world_happiness_index_df.to_sql(name='happiness', con=engine, if_exists='append', index=False)

# %%
alcoholSubstanceAbuse_df.to_sql(name='alcohol_consumption', con=engine, if_exists='append', index=False)

# %%
antidepressant_consumption_df.to_sql(name='antidepressant_consumption', con=engine, if_exists='append', index=False)

# %% [markdown]
# # SQL Queries Test

# %%
connection = engine.connect()

# %%
happiness_df = pd.read_sql("SELECT * FROM happiness", connection)
happiness_df.head()
# Out:
#    id      country  happiness_rank  happiness_score  gdp_per_capita  family  \
# 0   1  Switzerland               1            7.587          1.3965  1.3495
# 1   2      Iceland               2            7.561          1.3023  1.4022
# 2   3      Denmark               3            7.527          1.3255  1.3606
# 3   4       Norway               4            7.522          1.4590  1.3310
# 4   5       Canada               5            7.427          1.3263  1.3226
#
#    life_expectancy  freedom  trust_government  generosity  dystopia_residual  \
# 0           0.9414   0.6656            0.4198      0.2968             2.5174
# 1           0.9478   0.6288            0.1415      0.4363             2.7020
# 2           0.8746   0.6494            0.4836      0.3414             2.4920
# 3           0.8852   0.6697            0.3650      0.3470             2.4653
# 4           0.9056   0.6330            0.3296      0.4581             2.4518
#
#    year
# 0  2015
# 1  2015
# 2  2015
# ...

# %%
# happiness_df.to_html("happiness.html",index = False, header = True, border = 1, justify = 'left')
connection.close()
